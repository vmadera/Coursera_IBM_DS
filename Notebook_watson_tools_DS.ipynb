# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Victor Madera**<br>
# My desired occupation is to work as a data scientist in the service sector, in this way to be able to tell through stories, the path that data reveals towards optimization

# %% [markdown]
# *I'm interested in data science because I like the way data helps us make better decisions.
# Since I like math and programming I feel like I can help some companies achieve data-driven goals.*

# %% [markdown]
# ### The code below shows the result of multiplying 8 by 9

# %%
print(8*9)
# Out:
# 72

# %% [markdown]
# 1. Watson Studio<br><br>
# - Watson Studio is an IBM product<br>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/51/IBM_logo.svg/368px-IBM_logo.svg.png" alt="IBM Cloud" title="IBM Cloud Image" /> <br>
#
# >It's important review the Watson Studio cheatsheet
#
#
# - Watson Studio cheatsheet<br><br>
# <a href="https://www.ibm.com/docs/en/SSQNUZ_4.5.x/wsj/analyze-data/markd-jupyter.html" target="_blank" rel="noopener noreferrer">Markdown cheatsheet (Watson Studio)</a><br><br>
#
# - ~~Delete this please~~
